# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m"updated"
# Out:
# [main 594b704] updated
#  2 files changed, 44 insertions(+), 6 deletions(-)

# %%
# !git push

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m"updated"
# Out:
# [main 8359f6e] updated
#  5 files changed, 3574 insertions(+), 3015 deletions(-)
#  create mode 100644 .ipynb_checkpoints/Heart_Diesease_Prediction_Final-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/Heart_Disease_Project_Complete-checkpoint.ipynb

# %%
# !git push
# Out:
# To https://github.com/Arpithanj/Heart_Disease_Prediction.git
#    8d778e2..8359f6e  main -> main

# %%
# !git pull
# Out:
# Already up to date.
